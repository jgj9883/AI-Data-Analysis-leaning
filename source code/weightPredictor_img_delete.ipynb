# %%
import os, glob

# %%
data_dir = 'C:/Users/USER/Desktop/새 폴더/**'
FileList = glob.glob(data_dir + '/*.jpg')
img_namess = FileList

# %%
for idx, d in enumerate(img_namess):
    if "weightPredictionResult" in d : os.remove(d)
